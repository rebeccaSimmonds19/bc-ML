# %%
# import dependencies
# data cleaning and manipulation 

from sklearn.datasets import load_breast_cancer

import pandas as pd
import numpy as np

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# machine learning
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn import neighbors
from sklearn.metrics import confusion_matrix, classification_report, precision_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plot



# load dataset
data = load_breast_cancer()
# feature matrix
X = data.data
# target vector
y = data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.99, random_state=40)

clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(X_train, y_train)

# predict the test data and show the first 5 predictions
predictions = clf.predict(X)

i = 0
c_train = 0
while i < len(predictions):
    if predictions[i] == 1:
        c_train = c_train +1
    i = i+1
#c_train = .count_nonzero(y == 1)
nc_train = np.count_nonzero(y == 0)
c_predict = np.count_nonzero(predictions == 1)
nc_predict = np.count_nonzero(predictions == 0)

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
bar1 = plt.bar("cancer training",c_train, align='center', alpha=0.5)
bar2 = plt.bar("no cancer training",nc_train, align='center', alpha=0.5)
bar3 = plt.bar("cancer predict",c_predict, align='center', alpha=0.5)
bar4 = plt.bar("no cancer predict",nc_predict, align='center', alpha=0.5)

for rect in bar1 + bar2 + bar3 + bar4:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

#plt.xticks(y_pos, objects)
plt.ylabel('Number of results')
plt.title('Predicting cancer')

plt.show()
